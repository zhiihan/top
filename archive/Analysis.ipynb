# %%
import numpy as np # generic math functions
import matplotlib.pyplot as plt
import time
import scipy

# %%
#OLD DATA

N_min, N_max = (5, 11)

delta_E_matrix = np.zeros((N_max-N_min,20))
M_expval_matrix = np.zeros((N_max-N_min,20))
O_expval_matrix = np.zeros((N_max-N_min,20))

for i, N in enumerate(range(N_min, N_max)):
    delta_E_matrix[i, :] = np.load(r'/media/maciejko/zhan/top/data/delta_E_'+str(N)+'.npy')
    M_expval_matrix[i, :] = np.load(r'/media/maciejko/zhan/top/data/M_expval_'+str(N)+'.npy')
    O_expval_matrix[i, :] = np.load(r'/media/maciejko/zhan/top/data/O_expval_'+str(N)+'.npy')
    
delta_E_matrix = abs(delta_E_matrix)
M_expval_matrix = abs(M_expval_matrix)
O_expval_matrix = abs(O_expval_matrix)

# %%
for i, N in enumerate(range(N_min, N_max)):
    plt.plot(np.arange(0,2,step=0.1),delta_E_matrix[i,:])
    plt.scatter(np.arange(0,2,step=0.1),delta_E_matrix[i,:],label='N='+str(N))
plt.xlabel('J/h')
plt.ylabel('(E_1 - E_0)')
plt.title('Lowest state transition as a function of J/h')
plt.legend()
plt.savefig('/media/maciejko/zhan/top/plots/Band Gap.png')
plt.savefig('/media/maciejko/zhan/top/plots/Band Gap.pdf')

# %%
for i, N in enumerate(range(N_min, N_max)):
    plt.plot(np.arange(0,2,step=0.1),expval_matrix[i,:])
    plt.scatter(np.arange(0,2,step=0.1),expval_matrix[i,:],label='N='+str(N))
plt.xlabel('J/h')
plt.ylabel('Expval of M^2')
plt.ylim(bottom=0,top=1)
plt.title('Expval of M^2')
plt.legend()
plt.savefig('/media/maciejko/zhan/top/plots/Expval.png')
plt.savefig('/media/maciejko/zhan/top/plots/Expval.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a59a116c0ce1> in <module>
#       1 for i, N in enumerate(range(N_min, N_max)):
# ----> 2     plt.plot(np.arange(0,2,step=0.1),expval_matrix[i,:])
#       3     plt.scatter(np.arange(0,2,step=0.1),expval_matrix[i,:],label='N='+str(N))
#       4 plt.xlabel('J/h')
#       5 plt.ylabel('Expval of M^2')
#
# NameError: name 'expval_matrix' is not defined

# %%
for i, N in enumerate(range(N_min, N_max)):
    plt.plot(np.arange(0,2,step=0.1),O_expval_matrix[i,:])
    plt.scatter(np.arange(0,2,step=0.1),O_expval_matrix[i,:],label='N='+str(N))
plt.xlabel('J/h')
plt.ylabel('Expval of O^2 on ground state')
plt.title('Expval of O^2 on ground state')

plt.legend()
plt.savefig('/media/maciejko/zhan/top/plots/O_Expval.png')
plt.savefig('/media/maciejko/zhan/top/plots/O_Expval.pdf')

# %%
#NEW DATA

N_min, N_max = (5, 14)

delta_E_matrix = np.zeros((N_max-N_min,20))
M_expval_matrix = np.zeros((N_max-N_min,20))
O_expval_matrix = np.zeros((N_max-N_min,20))

for i, N in enumerate(range(N_min, N_max)):
    delta_E_matrix[i, :] = np.load(r'/media/maciejko/zhan/top/data/delta_E_ksym'+str(N)+'.npy')
    M_expval_matrix[i, :] = np.load(r'/media/maciejko/zhan/top/data/M_expval_ksym'+str(N)+'.npy')
    O_expval_matrix[i, :] = np.load(r'/media/maciejko/zhan/top/data/O_expval_ksym'+str(N)+'.npy')
    
delta_E_matrix = abs(delta_E_matrix)
M_expval_matrix = abs(M_expval_matrix)
O_expval_matrix = abs(O_expval_matrix)

# %%
for i, N in enumerate(range(N_min, N_max)):
    plt.plot(np.arange(0,2,step=0.1),delta_E_matrix[i,:])
    plt.scatter(np.arange(0,2,step=0.1),delta_E_matrix[i,:],label='N='+str(N))
plt.xlabel('J/h')
plt.ylabel('(E_1 - E_0)')
plt.title('Band Gap vs. J/h with momentum = 0')
plt.legend(loc=1)
plt.savefig('/media/maciejko/zhan/top/plots/Band Gap Momentum.png')
plt.savefig('/media/maciejko/zhan/top/plots/Band Gap Momentum.pdf')

# %%
for i, N in enumerate(range(N_min, N_max)):
    plt.plot(np.arange(0,2,step=0.1),O_expval_matrix[i,:])
    plt.scatter(np.arange(0,2,step=0.1),O_expval_matrix[i,:],label='N='+str(N))
plt.xlabel('J/h')
plt.ylabel('Expval of O^2 on ground state')
plt.title('Expval of O^2 on ground state with momentum = 0')

plt.legend()
plt.savefig('/media/maciejko/zhan/top/plots/O_Expval_Momentum.png')
plt.savefig('/media/maciejko/zhan/top/plots/O_Expval_Momentum.pdf')

# %%
for i, N in enumerate(range(N_min, N_max)):
    plt.plot(np.arange(0,2,step=0.1),O_expval_matrix[i,:])
    plt.scatter(np.arange(0,2,step=0.1),O_expval_matrix[i,:],label='N='+str(N))
plt.xlabel('J/h')
plt.ylabel('Expval of O^2')
plt.title('Expval of O^2 with momentum = 0')
plt.legend()
#plt.savefig('/media/maciejko/zhan/top/plots/O_Expval_Momentum.png')
#plt.savefig('/media/maciejko/zhan/top/plots/O_Expval_Momentum.pdf')
